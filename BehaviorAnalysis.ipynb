# %% [markdown]
# <a href="https://colab.research.google.com/github/chamiepr/Research-Project/blob/shashini/BehaviorAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xgboost
from xgboost import XGBClassifier
